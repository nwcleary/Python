# %%
import matplotlib as plt
import numpy as np 
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_excel("RentalApplication_Data.xlsx")

# %%
df
# Out:
#                  Time  \
# 0 2020-04-26 18:08:03
# 1 2020-04-28 09:15:24
#
#   Which Rental Property Address Are You Applying For? (Address)  \
# 0           2485 Armstrong Pl, Santa Clara, CA 95050
# 1                              2852 Forest Hill Blvd
#
#    Which Rental Property Address Are You Applying For? (Address2)  \
# 0                                                NaN
# 1                                                NaN
#
#   Which Rental Property Address Are You Applying For? (City)  \
# 0                                        Santa Clara
# 1                                      Pacific Grove
#
#   Which Rental Property Address Are You Applying For? (State)  \
# 0                                                 CA
# 1                                                 CA
#
#    Which Rental Property Address Are You Applying For? (Zip)  \
# 0                                              95050
# 1                                              93950
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Columns: 247 entries, Time to Location
# dtypes: datetime64[ns](5), float64(162), int64(14), object(66)
# memory usage: 4.0+ KB

# %%
df.describe()
# Out:
#        Which Rental Property Address Are You Applying For? (Address2)  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        Which Rental Property Address Are You Applying For? (Zip)  \
# count                                           2.000000
# mean                                        94500.000000
# std                                           777.817459
# min                                         93950.000000
# 25%                                         94225.000000
# 50%                                         94500.000000
# ...

# %%
df_name = df['Name (First)']

# %%
df_name
# Out:
# 0    Zhirong
# 1     Sherry
# Name: Name (First), dtype: object
